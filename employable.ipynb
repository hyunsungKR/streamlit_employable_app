# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('Documents/YH_python/data/Student-Employability-Datasets.csv')

# %%
df
# Out:
#      Name of Student  GENERAL APPEARANCE  MANNER OF SPEAKING  \
# 0          Student 1                   4                   5
# 1          Student 2                   4                   4
# 2          Student 3                   4                   3
# 3          Student 4                   3                   3
# 4          Student 5                   4                   4
# ...              ...                 ...                 ...
# 2977    Student 2996                   4                   3
# 2978    Student 2997                   3                   4
# 2979    Student 2998                   4                   5
# 2980    Student 2999                   4                   4
# 2981    Student 3000                   4                   4
#
#       PHYSICAL CONDITION  MENTAL ALERTNESS  SELF-CONFIDENCE  \
# 0                      4                 5                5
# 1                      4                 4                4
# ...

# %%
df=df.drop('Name of Student',axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2982 entries, 0 to 2981
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   GENERAL APPEARANCE          2982 non-null   int64
#  1   MANNER OF SPEAKING          2982 non-null   int64
#  2   PHYSICAL CONDITION          2982 non-null   int64
#  3   MENTAL ALERTNESS            2982 non-null   int64
#  4   SELF-CONFIDENCE             2982 non-null   int64
#  5   ABILITY TO PRESENT IDEAS    2982 non-null   int64
#  6   COMMUNICATION SKILLS        2982 non-null   int64
#  7   Student Performance Rating  2982 non-null   int64
#  8   CLASS                       2982 non-null   object
# dtypes: int64(8), object(1)
# memory usage: 209.8+ KB

# %%
df.describe()
# Out:
#        GENERAL APPEARANCE  MANNER OF SPEAKING  PHYSICAL CONDITION  \
# count         2982.000000         2982.000000         2982.000000
# mean             4.246814            3.884641            3.972166
# std              0.678501            0.757013            0.744135
# min              2.000000            2.000000            2.000000
# 25%              4.000000            3.000000            3.000000
# 50%              4.000000            4.000000            4.000000
# 75%              5.000000            4.000000            5.000000
# max              5.000000            5.000000            5.000000
#
#        MENTAL ALERTNESS  SELF-CONFIDENCE  ABILITY TO PRESENT IDEAS  \
# count       2982.000000      2982.000000               2982.000000
# mean           3.962777         3.910798                  3.813883
# std            0.781982         0.807602                  0.739390
# min            2.000000         2.000000                  2.000000
# ...

# %%
# Out:
#       GENERAL APPEARANCE  MANNER OF SPEAKING  PHYSICAL CONDITION  \
# 0                      4                   5                   4
# 1                      4                   4                   4
# 2                      4                   3                   3
# 3                      3                   3                   3
# 4                      4                   4                   3
# ...                  ...                 ...                 ...
# 2977                   4                   3                   3
# 2978                   3                   4                   4
# 2979                   4                   5                   4
# 2980                   4                   4                   4
# 2981                   4                   4                   4
#
#       MENTAL ALERTNESS  SELF-CONFIDENCE  ABILITY TO PRESENT IDEAS  \
# 0                    5                5                         5
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [57], line 1
# ----> 1 if df['CLASS'] == 'Employable' :
#       2     df['CLASS2'] = 1
#       3 else :
#
# File ~\Anaconda3\envs\YH\lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self):
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df = df.replace('LessEmployable', 0)

# %%
df = df.replace('Employable', 1)

# %%
df
# Out:
#       GENERAL APPEARANCE  MANNER OF SPEAKING  PHYSICAL CONDITION  \
# 0                      4                   5                   4
# 1                      4                   4                   4
# 2                      4                   3                   3
# 3                      3                   3                   3
# 4                      4                   4                   3
# ...                  ...                 ...                 ...
# 2977                   4                   3                   3
# 2978                   3                   4                   4
# 2979                   4                   5                   4
# 2980                   4                   4                   4
# 2981                   4                   4                   4
#
#       MENTAL ALERTNESS  SELF-CONFIDENCE  ABILITY TO PRESENT IDEAS  \
# 0                    5                5                         5
# ...

# %%
df.groupby('CLASS')['GENERAL APPEARANCE'].value_counts()
# Out:
# CLASS  GENERAL APPEARANCE
# 0      4                     718
#        5                     372
#        3                     147
#        2                      16
# 1      4                     758
#        5                     757
#        3                     214
# Name: GENERAL APPEARANCE, dtype: int64

# %%
X = df.iloc[:,:-1]

# %%
X
# Out:
#       GENERAL APPEARANCE  MANNER OF SPEAKING  PHYSICAL CONDITION  \
# 0                      4                   5                   4
# 1                      4                   4                   4
# 2                      4                   3                   3
# 3                      3                   3                   3
# 4                      4                   4                   3
# ...                  ...                 ...                 ...
# 2977                   4                   3                   3
# 2978                   3                   4                   4
# 2979                   4                   5                   4
# 2980                   4                   4                   4
# 2981                   4                   4                   4
#
#       MENTAL ALERTNESS  SELF-CONFIDENCE  ABILITY TO PRESENT IDEAS  \
# 0                    5                5                         5
# ...

# %%
y = df['CLASS']

# %%
y
# Out:
# 0       1
# 1       1
# 2       0
# 3       0
# 4       1
#        ..
# 2977    1
# 2978    1
# 2979    1
# 2980    0
# 2981    1
# Name: CLASS, Length: 2982, dtype: int64

# %%
# 피쳐스케일링
from sklearn.preprocessing import MinMaxScaler
scaler_X = MinMaxScaler()
X=scaler_X.fit_transform(X)

# %%
# training / test 셋으로 분리
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1)

# %%
# 모델링
from sklearn.ensemble import RandomForestClassifier
classifier=RandomForestClassifier(n_estimators=100)
classifier.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cm=confusion_matrix(y_test,y_pred)

# %%
cm
# Out:
# array([[210,  38],
#        [ 21, 328]], dtype=int64)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9011725293132329

# %%
classifier
# Out:
# RandomForestClassifier()

# %%
scaler_X
# Out:
# MinMaxScaler()

# %%
import joblib

# %%
joblib.dump(classifier,'classifier.pkl')
# Out:
# ['classifier.pkl']

# %%
joblib.dump(scaler_X,'scaler_X.pkl')
# Out:
# ['scaler_X.pkl']

# %%
new_data = np.array([3,3,4,5,4,5,4,5]).reshape(1,8)

# %%
new_data = scaler_X.transform(new_data)

# %%
classifier.predict(new_data) == 1
# Out:
# array([ True])
